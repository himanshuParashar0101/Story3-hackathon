# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'The Celestial Harmony',
    'body': (
        "In the cosmic expanse where stars weave tales of ancient wisdom, Captain Orion embarks on a celestial odyssey. "
        "Guided by the ethereal vibrations of a sentient star cluster, Orion's spacecraft transforms into a cosmic instrument, "
        "composing symphonies that resonate across galaxies."
    ),
    'tags': ['Celestial Odyssey', 'Ethereal Vibrations', 'Cosmic Instrument', 'Galactic Harmony'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "As Captain Orion delves deeper into the celestial expanse, a sentient star cluster imparts ancient wisdom. "
        "The Harmony Keeper reveals that each twinkle of a star is a cosmic language, and each galaxy is a verse in the poetry "
        "of the universe. Orion's spacecraft transforms into a cosmic instrument, composing symphonies that resonate across galaxies, "
        "awakening dormant celestial beings and unlocking hidden realms."
    ),
    'title': 'Harmony of Celestial Vibrations',
    'tags': ['Sentient Star Cluster', 'Cosmic Language', 'Celestial Symphony', 'Hidden Realms'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "In the heart of the celestial odyssey, Captain Orion stumbles upon a cosmic anomaly that threatens to unravel the stability "
        "of the multiverse. The anomaly pulses with unpredictable quantum fluctuations, creating rifts between dimensions. Orion faces a "
        "moral dilemma — whether to close the anomaly and restore balance or harness its power to explore uncharted realms."
    ),
    'title': 'Rifts of Destiny',
    'tags': ['Cosmic Anomaly', 'Multiverse Stability', 'Moral Dilemma', 'Quantum Fluctuations'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "Amidst the cosmic symphony, Captain Orion encounters an ancient cosmic entity that holds the key to transcending the boundaries "
        "of space and time. The entity challenges Orion to unlock the true potential of consciousness, bridging the gap between mortal existence "
        "and cosmic enlightenment."
    ),
    'title': 'Transcendence of Consciousness',
    'tags': ['Cosmic Entity', 'Space-Time Boundaries', 'Cosmic Enlightenment', 'Transcendental Journey'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
