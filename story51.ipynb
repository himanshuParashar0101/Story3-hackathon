# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'Chronicles of the Celestial Wanderer',
    'body': (
        "In the celestial realm, a mysterious wanderer named Seraphina roams the cosmic landscapes. Guided by a celestial compass, "
        "Seraphina seeks to uncover the forgotten tales of celestial beings and their connection to the fabric of the universe."
    ),
    'tags': ['Celestial', 'Cosmic Wanderer', 'Mystery', 'Adventure'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "As Seraphina delves deeper into the celestial realms, she encounters an ancient star oracle. The oracle possesses cosmic "
        "wisdom and reveals glimpses of the future. Seraphina must choose whether to embrace or alter the unfolding destiny."
    ),
    'title': 'Oracles of Cosmic Destiny',
    'tags': ['Ancient Star Oracle', 'Cosmic Wisdom', 'Future Glimpses', 'Destiny'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "In the cosmic archives, Seraphina discovers a forgotten constellation that holds the key to unlocking celestial powers. "
        "She faces a moral dilemma—whether to share the knowledge with the celestial community or keep it hidden for personal gain."
    ),
    'title': 'Constellation of Ethereal Powers',
    'tags': ['Forgotten Constellation', 'Celestial Powers', 'Moral Dilemma', 'Hidden Knowledge'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "As Seraphina's journey unfolds, she encounters a cosmic anomaly threatening the balance of the celestial realms. "
        "She must decide whether to intervene and restore harmony or allow the anomaly to reshape the cosmic order."
    ),
    'title': 'Harmonys Celestial Test',
    'tags': ['Cosmic Anomaly', 'Balance', 'Harmony', 'Celestial Realms'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'xM4kAorLk3KmPNWQ', 'authorId': '1932', 'title': 'Chronicles of the Celestial Wanderer', 'body': 'In the celestial realm, a mysterious wanderer named Seraphina roams the cosmic landscapes. Guided by a celestial compass, Seraphina seeks to uncover the forgotten tales of celestial beings and their connection to the fabric of the universe.', 'lang': 'en', 'createdAt': '2024-01-26T11:05:30.373Z', 'updatedAt': '2024-01-26T11:05:30.373Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# First Twist created successfully: {'hashId': 'DG3LRJnLEYwydO7v', 'authorId': '1932', 'title': 'Oracles of Cosmic Destiny', 'body': 'As Seraphina delves deeper into the celestial realms, she encounters an ancient star oracle. The oracle possesses cosmic wisdom and reveals glimpses of the future. Seraphina must choose whether to embrace or alter the unfolding destiny.', 'lang': 'en', 'createdAt': '2024-01-26T11:05:32.536Z', 'updatedAt': '2024-01-26T11:05:32.536Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'xM4kAorLk3KmPNWQ', 'hashRootId': 'xM4kAorLk3KmPNWQ', 'isExtraTwist': False, 'closestHashRootId': 'xM4kAorLk3KmPNWQ'}
# Second Twist created successfully: {'hashId': 'yQE3joxLpXoL7bMx', 'authorId': '1932', 'title': 'Constellation of Ethereal Powers', 'body': 'In the cosmic archives, Seraphina discovers a forgotten constellation that holds the key to unlocking celestial powers. She faces a moral dilemma—whether to share the knowledge with the celestial community or keep it hidden for personal gain.', 'lang': 'en', 'createdAt': '2024-01-26T11:05:33.653Z', 'updatedAt': '2024-01-26T11:05:33.653Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'DG3LRJnLEYwydO7v', 'hashRootId': 'xM4kAorLk3KmPNWQ', 'isExtraTwist': False, 'closestHashRootId': 'xM4kAorLk3KmPNWQ'}
# Third Twist created successfully: {'hashId': 'lyme0og6mpw9BY1k', 'authorId': '1932', 'title': 'Harmonys Celestial Test', 'body': "As Seraphina's journey unfolds, she encounters a cosmic anomaly threatening the balance of the celestial realms. She must decide whether to intervene and restore harmony or allow the anomaly to reshape the cosmic order.", 'lang': 'en', 'createdAt': '2024-01-26T11:05:34.774Z', 'updatedAt': '2024-01-26T11:05:34.774Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'yQE3joxLpXoL7bMx', 'hashRootId': 'xM4kAorLk3KmPNWQ', 'isExtraTwist': False, 'closestHashRootId': 'xM4kAorLk3KmPNWQ'}
