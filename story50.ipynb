# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'Chronicles of Celestial Echoes',
    'body': (
        "In the cosmic tapestry of the universe, a celestial wanderer named Seraphina embarks on an odyssey among the stars. Guided by ancient prophecies, "
        "she discovers an ethereal phenomenon—the Celestial Echoes. These mystical echoes hold the secrets of cosmic balance and the interconnectedness of all "
        "celestial beings."
    ),
    'tags': ['Cosmic Odyssey', 'Celestial Wonders', 'Prophecies', 'Interconnected Universe'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "As Seraphina delves deeper into the cosmic expanse, she encounters a sentient star cluster with the ability to communicate through ethereal vibrations. "
        "This celestial entity imparts ancient wisdom, revealing the interconnected nature of galaxies."
    ),
    'title': 'Harmony of Celestial Vibrations',
    'tags': ['Sentient Star Cluster', 'Cosmic Language', 'Celestial Wisdom', 'Interconnected Galaxies'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "Guided by the harmonies of the cosmos, Seraphina's spacecraft transforms into a cosmic instrument. Together, they compose symphonies that resonate across the "
        "galaxies, awakening dormant celestial beings and unlocking hidden realms."
    ),
    'title': 'Symphonies of the Cosmos',
    'tags': ['Cosmic Harmony', 'Galactic Instrument', 'Awakening', 'Hidden Realms'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "In the heart of a distant galaxy, Seraphina confronts the enigma of existence itself. The Celestial Echoes guide her to unlock the secrets of the cosmic tapestry."
    ),
    'title': 'Enigma of Existence',
    'tags': ['Distant Galaxy', 'Cosmic Tapestry', 'Unlocking Secrets', 'Celestial Guidance'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'rm8DeK5O0No9zagq', 'authorId': '1932', 'title': 'Chronicles of Celestial Echoes', 'body': 'In the cosmic tapestry of the universe, a celestial wanderer named Seraphina embarks on an odyssey among the stars. Guided by ancient prophecies, she discovers an ethereal phenomenon—the Celestial Echoes. These mystical echoes hold the secrets of cosmic balance and the interconnectedness of all celestial beings.', 'lang': 'en', 'createdAt': '2024-01-26T11:05:01.259Z', 'updatedAt': '2024-01-26T11:05:01.259Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# First Twist created successfully: {'hashId': 'Q04pmJRVqzJbOW6N', 'authorId': '1932', 'title': 'Harmony of Celestial Vibrations', 'body': 'As Seraphina delves deeper into the cosmic expanse, she encounters a sentient star cluster with the ability to communicate through ethereal vibrations. This celestial entity imparts ancient wisdom, revealing the interconnected nature of galaxies.', 'lang': 'en', 'createdAt': '2024-01-26T11:05:04.062Z', 'updatedAt': '2024-01-26T11:05:04.062Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'rm8DeK5O0No9zagq', 'hashRootId': 'rm8DeK5O0No9zagq', 'isExtraTwist': False, 'closestHashRootId': 'rm8DeK5O0No9zagq'}
# Second Twist created successfully: {'hashId': 'Nzy19JpLNZJePgXv', 'authorId': '1932', 'title': 'Symphonies of the Cosmos', 'body': "Guided by the harmonies of the cosmos, Seraphina's spacecraft transforms into a cosmic instrument. Together, they compose symphonies that resonate across the galaxies, awakening dormant celestial beings and unlocking hidden realms.", 'lang': 'en', 'createdAt': '2024-01-26T11:05:05.808Z', 'updatedAt': '2024-01-26T11:05:05.808Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'Q04pmJRVqzJbOW6N', 'hashRootId': 'rm8DeK5O0No9zagq', 'isExtraTwist': False, 'closestHashRootId': 'rm8DeK5O0No9zagq'}
# Third Twist created successfully: {'hashId': 'QNePGwQgqEJLyBnD', 'authorId': '1932', 'title': 'Enigma of Existence', 'body': 'In the heart of a distant galaxy, Seraphina confronts the enigma of existence itself. The Celestial Echoes guide her to unlock the secrets of the cosmic tapestry.', 'lang': 'en', 'createdAt': '2024-01-26T11:05:07.297Z', 'updatedAt': '2024-01-26T11:05:07.297Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'Nzy19JpLNZJePgXv', 'hashRootId': 'rm8DeK5O0No9zagq', 'isExtraTwist': False, 'closestHashRootId': 'rm8DeK5O0No9zagq'}
