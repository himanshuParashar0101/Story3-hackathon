# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data for Story 11
new_story_data = {
    'title': 'Whispers of Varanasi',
    'body': (
        "In the ancient city of Varanasi, 'Whispers of Varanasi' unfolds the tale of a young artist who discovers a hidden "
        "dimension where echoes of ancient wisdom and artistic inspiration converge. The ghats along the Ganges become a gateway to "
        "a mystical realm where art, spirituality, and the vibrancy of Indian culture intertwine.\n\n"
        "Each stroke of the artist's brush reveals glimpses of celestial beings, and every note of the sitar carries the resonance of "
        "timeless melodies. 'Whispers of Varanasi' becomes a journey of artistic enlightenment, exploring the transformative power of "
        "creativity in the heart of India."
    ),
    'tags': ['Varanasi', 'Artistic Inspiration', 'Ganges Ghats', 'Indian Culture'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# First twist data for Story 11
first_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "As the artist delves deeper into the mystical realm, they encounter ethereal muses who guide them in transcending the boundaries "
        "of traditional art. 'Whispers of Varanasi' transforms into a visual symphony, exploring the fusion of traditional and abstract art "
        "styles inspired by the spiritual energy of Varanasi."
    ),
    'title': 'Ethereal Muses',
    'tags': ['Artistic Transcendence', 'Visual Symphony', 'Abstract Art', 'Spiritual Energy'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=first_twist_data)

if response.status_code == 201:
    first_twist_info = response.json()
    print(f'First Twist created successfully: {first_twist_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Second twist data for Story 11
second_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': first_twist_info['hashId'],
    'body': (
        "In the heart of Varanasi's artistic dimension, the artist discovers a portal leading to forgotten tales woven into the fabric "
        "of the city. A choice emerges — to become a storyteller preserving ancient narratives or to create new stories for generations to come. "
        "'Whispers of Varanasi' becomes a celebration of storytelling, bridging the gap between past and present in the soul of India."
    ),
    'title': 'Portal of Forgotten Tales',
    'tags': ['Storytelling', 'Ancient Narratives', 'Cultural Preservation', 'Bridging Past and Present'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=second_twist_data)

if response.status_code == 201:
    second_twist_info = response.json()
    print(f'Second Twist created successfully: {second_twist_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'd4NXzJDL0YJWe285', 'authorId': '1932', 'title': 'Whispers of Varanasi', 'body': "In the ancient city of Varanasi, 'Whispers of Varanasi' unfolds the tale of a young artist who discovers a hidden dimension where echoes of ancient wisdom and artistic inspiration converge. The ghats along the Ganges become a gateway to a mystical realm where art, spirituality, and the vibrancy of Indian culture intertwine.\n\nEach stroke of the artist's brush reveals glimpses of celestial beings, and every note of the sitar carries the resonance of timeless melodies. 'Whispers of Varanasi' becomes a journey of artistic enlightenment, exploring the transformative power of creativity in the heart of India.", 'lang': 'en', 'createdAt': '2024-01-07T16:05:20.661Z', 'updatedAt': '2024-01-07T16:05:20.661Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# ...
