# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'The Ethereal Odyssey',
    'body': (
        "Embark on an ethereal odyssey through the cosmos with Captain Seraphina. As she navigates the celestial tapestry, "
        "mystical constellations come to life, revealing ancient secrets. The spaceship becomes a vessel of transcendence, "
        "bridging the realms between the material and the spiritual."
    ),
    'tags': ['Ethereal Odyssey', 'Cosmic Exploration', 'Mystical Constellations', 'Spiritual Transcendence'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "In the heart of the celestial odyssey, Captain Seraphina encounters the Astral Guardians—celestial beings tasked "
        "with maintaining balance in the cosmos. They reveal a cosmic imbalance threatening the fabric of reality, and Seraphina "
        "must decide whether to intervene and restore harmony."
    ),
    'title': 'Harmony's Guardians',
    'tags': ['Astral Guardians', 'Cosmic Imbalance', 'Reality Harmony', 'Celestial Intervention'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "As the ethereal odyssey unfolds, Captain Seraphina discovers a cosmic library at the nexus of dimensions. The Library "
        "of Eternity contains the collective knowledge of all civilizations. Seraphina faces the temptation to access forbidden wisdom "
        "that could alter the course of history."
    ),
    'title': 'Library of Eternity',
    'tags': ['Cosmic Library', 'Forbidden Wisdom', 'Nexus of Dimensions', 'Temporal Temptation'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "In the climax of the ethereal odyssey, Captain Seraphina confronts the Cosmic Weaver—an entity responsible for weaving the "
        "threads of destiny. The Weaver presents a choice: embrace the predetermined fate or unravel the cosmic threads and forge a new destiny."
    ),
    'title': 'Weavers Choice',
    'tags': ['Cosmic Weaver', 'Threads of Destiny', 'Predetermined Fate', 'Forge a New Destiny'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
#   Cell In[1], line 49
#     'title': 'Harmony's Guardians',
#                                  ^
# SyntaxError: unterminated string literal (detected at line 49)
