# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'The Enchanted Odyssey',
    'body': (
        "Embark on an enchanted odyssey with Eli, a young adventurer with a deep connection to the cosmic energies. Elis journey unfolds in a realm where magic and mysticism converge, revealing hidden wonders and ancient secrets."
    ),
    'tags': ['Adventure', 'Fantasy', 'Magic', 'Mysticism'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "In the heart of the enchanted odyssey, Eli discovers a hidden sanctuary where ancient magical beings reside. The beings, attuned to the rhythms of the cosmos, offer Eli the chance to unlock dormant magical abilities. The odyssey transforms into a magical training, where Eli learns to wield elemental forces and harmonize with the mystical energies of the enchanted realms."
    ),
    'title': 'Harmony of Elemental Magic',
    'tags': ['Hidden Sanctuary', 'Magical Beings', 'Elemental Magic', 'Cosmic Harmonization'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "As Eli delves deeper into the magical realms, they encounter ancient guardians tasked with preserving the balance of cosmic forces. These mystical beings challenge Eli to prove their worthiness by overcoming trials that test the adventurers resolve and connection to the cosmic energies."
    ),
    'title': 'Trials of Cosmic Balance',
    'tags': ['Ancient Guardians', 'Cosmic Forces', 'Trials', 'Resolve'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "In the climactic finale of the enchanted odyssey, Eli faces a choice that will determine the fate of the magical realms. A cosmic convergence approaches, and Eli must decide whether to embrace their newfound powers to restore harmony or resist the cosmic forces and preserve the natural order."
    ),
    'title': 'Cosmic Convergence',
    'tags': ['Climactic Finale', 'Fate', 'Harmony', 'Cosmic Forces'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'Wk7YNJ69Daod6DRb', 'authorId': '1932', 'title': 'The Enchanted Odyssey', 'body': 'Embark on an enchanted odyssey with Eli, a young adventurer with a deep connection to the cosmic energies. Elis journey unfolds in a realm where magic and mysticism converge, revealing hidden wonders and ancient secrets.', 'lang': 'en', 'createdAt': '2024-01-26T10:12:33.516Z', 'updatedAt': '2024-01-26T10:12:33.516Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# First Twist created successfully: {'hashId': 'zWx48KZlBpoMqagE', 'authorId': '1932', 'title': 'Harmony of Elemental Magic', 'body': 'In the heart of the enchanted odyssey, Eli discovers a hidden sanctuary where ancient magical beings reside. The beings, attuned to the rhythms of the cosmos, offer Eli the chance to unlock dormant magical abilities. The odyssey transforms into a magical training, where Eli learns to wield elemental forces and harmonize with the mystical energies of the enchanted realms.', 'lang': 'en', 'createdAt': '2024-01-26T10:12:35.921Z', 'updatedAt': '2024-01-26T10:12:35.921Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'Wk7YNJ69Daod6DRb', 'hashRootId': 'Wk7YNJ69Daod6DRb', 'isExtraTwist': False, 'closestHashRootId': 'Wk7YNJ69Daod6DRb'}
# Second Twist created successfully: {'hashId': '97yxNJ482XJk64O3', 'authorId': '1932', 'title': 'Trials of Cosmic Balance', 'body': 'As Eli delves deeper into the magical realms, they encounter ancient guardians tasked with preserving the balance of cosmic forces. These mystical beings challenge Eli to prove their worthiness by overcoming trials that test the adventurers resolve and connection to the cosmic energies.', 'lang': 'en', 'createdAt': '2024-01-26T10:12:37.280Z', 'updatedAt': '2024-01-26T10:12:37.280Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'zWx48KZlBpoMqagE', 'hashRootId': 'Wk7YNJ69Daod6DRb', 'isExtraTwist': False, 'closestHashRootId': 'Wk7YNJ69Daod6DRb'}
# Third Twist created successfully: {'hashId': 'kQRaEJW87bKqZmPY', 'authorId': '1932', 'title': 'Cosmic Convergence', 'body': 'In the climactic finale of the enchanted odyssey, Eli faces a choice that will determine the fate of the magical realms. A cosmic convergence approaches, and Eli must decide whether to embrace their newfound powers to restore harmony or resist the cosmic forces and preserve the natural order.', 'lang': 'en', 'createdAt': '2024-01-26T10:12:38.828Z', 'updatedAt': '2024-01-26T10:12:38.828Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': '97yxNJ482XJk64O3', 'hashRootId': 'Wk7YNJ69Daod6DRb', 'isExtraTwist': False, 'closestHashRootId': 'Wk7YNJ69Daod6DRb'}
