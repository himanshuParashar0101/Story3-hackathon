# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'The Enchanted Odyssey',
    'body': (
        "In a realm of enchantment, where magic and reality intertwine, an ordinary adventurer named Eli embarks on an extraordinary odyssey. "
        "Guided by an ancient map infused with mystical energies, Eli discovers portals to enchanted realms, each governed by magical beings and "
        "guarded by mythical creatures.\n\n"
        "As Eli traverses through the enchanted realms, they encounter sentient forests, ethereal creatures, and realms shaped by the dreams of "
        "the mystical beings. The odyssey becomes a journey of self-discovery, where Eli learns to harness the magic within and embrace the "
        "responsibility that comes with it."
    ),
    'tags': ['Enchantment', 'Magic Realms', 'Mythical Creatures', 'Self-Discovery'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating new twists
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "In the heart of the enchanted odyssey, Eli discovers a hidden sanctuary where ancient magical beings reside. The beings, attuned to the "
        "rhythms of the cosmos, offer Eli the chance to unlock dormant magical abilities. The odyssey transforms into a magical training, where "
        "Eli learns to wield elemental forces and harmonize with the mystical energies of the enchanted realms."
    ),
    'title': 'Harmony of Elemental Magic',
    'tags': ['Hidden Sanctuary', 'Magical Beings', 'Elemental Magic', 'Cosmic Harmonization'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "As Eli delves deeper into the enchanted odyssey, they encounter a realm frozen in perpetual winter. A mysterious snow queen, guardian "
        "of the frosty domain, presents Eli with a choice — to restore the balance of the seasons or succumb to the eternal winter's embrace. "
        "The odyssey becomes a test of Eli's resilience and the consequences of decisions in the enchanted realms."
    ),
    'title': 'Frostbound Dilemma',
    'tags': ['Snow Queen', 'Eternal Winter', 'Seasonal Balance', 'Decision Consequences'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "In the final leg of the enchanted odyssey, Eli encounters a mythical oracle who reveals glimpses of the adventurer's destiny. The oracle's "
        "prophecy hints at a cosmic convergence where Eli's choices will shape the fate of the enchanted realms. The odyssey transforms into a "
        "soul-searching journey, where Eli confronts the weight of destiny and the power of free will."
    ),
    'title': 'Oracles Prophecy',
    'tags': ['Mythical Oracle', 'Cosmic Convergence', 'Destiny', 'Free Will'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# Error creating a new story. Status code: 401
# Error response: {'statusCode': 401, 'requestId': '07e774f07fe7714e86e0c7f17c185401', 'message': 'Unauthorized'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 45
#      41 twists_url = f'{base_url}/twists'
#      43 # Twist 1 data
#      44 twist1_data = {
# ---> 45     'hashId': selected_story_hash,
#      46     'hashParentId': selected_story_hash,
#      47     'body': (
#      48         "In the heart of the enchanted odyssey, Eli discovers a hidden sanctuary where ancient magical beings reside. The beings, attuned to the "
#      49         "rhythms of the cosmos, offer Eli the chance to unlock dormant magical abilities. The odyssey transforms into a magical training, where "
#      50         "Eli learns to wield elemental forces and harmonize with the mystical energies of the enchanted realms."
#      51     ),
#      52     'title': 'Harmony of Elemental Magic',
#      53     'tags': ['Hidden Sanctuary', 'Magical Beings', 'Elemental Magic', 'Cosmic Harmonization'],
#      54 }
#      56 # Make a POST request to create the first twist
#      57 response = requests.post(twists_url, headers=headers, json=twist1_data)
#
# NameError: name 'selected_story_hash' is not defined
