# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
   'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
      # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data for Story 14
new_story_data = {
    'title': 'The Rajput Legacy',
    'body': (
        "Amidst the opulent landscapes of Rajasthan, 'The Rajput Legacy' unfolds the saga of Rani Meher, a formidable leader "
        "and guardian of the Rajput heritage. As political intrigues threaten the ancestral throne, Rani Meher navigates the complexities "
        "of power while upholding the valor and honor of the Rajput lineage.\n\n"
        "The story becomes a tapestry woven with tales of chivalry, loyalty, and the enduring spirit of the Rajput warriors."
    ),
    'tags': ['Rajasthan', 'Rajput Heritage', 'Political Intrigues', 'Chivalry'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# First twist data for Story 14
first_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "In the royal courts of Rajasthan, Rani Meher uncovers a hidden artifact that holds the key to an ancient Rajput prophecy. "
        "'The Rajput Legacy' transforms into a quest to fulfill the prophecy, leading Rani Meher through treacherous landscapes and "
        "confrontations with those who seek to thwart destiny."
    ),
    'title': 'Prophecy Unveiled',
    'tags': ['Ancient Artifact', 'Rajput Prophecy', 'Royal Courts', 'Quest'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=first_twist_data)

if response.status_code == 201:
    first_twist_info = response.json()
    print(f'First Twist created successfully: {first_twist_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Second twist data for Story 14
second_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': first_twist_info['hashId'],
    'body': (
        "As Rani Meher progresses on the quest, she encounters a rival Rajput clan with a conflicting interpretation of the prophecy. "
        "'The Rajput Legacy' becomes a tale of rivalries, alliances, and the ultimate battle for the preservation of Rajput heritage."
    ),
    'title': 'Clash of Legacies',
    'tags': ['Rival Rajput Clan', 'Interpretation Conflict', 'Alliances', 'Battle for Heritage'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=second_twist_data)

if response.status_code == 201:
    second_twist_info = response.json()
    print(f'Second Twist created successfully: {second_twist_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'WyPmZoBLZ4K9anDQ', 'authorId': '1932', 'title': 'The Rajput Legacy', 'body': "Amidst the opulent landscapes of Rajasthan, 'The Rajput Legacy' unfolds the saga of Rani Meher, a formidable leader and guardian of the Rajput heritage. As political intrigues threaten the ancestral throne, Rani Meher navigates the complexities of power while upholding the valor and honor of the Rajput lineage.\n\nThe story becomes a tapestry woven with tales of chivalry, loyalty, and the enduring spirit of the Rajput warriors.", 'lang': 'en', 'createdAt': '2024-01-07T16:13:13.264Z', 'updatedAt': '2024-01-07T16:13:13.264Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# First Twist created successfully: {'hashId': 'OAMNrJNLpEw4Wpnv', 'authorId': '1932', 'title': 'Prophecy Unveiled', 'body': "In the royal courts of Rajasthan, Rani Meher uncovers a hidden artifact that holds the key to an ancient Rajput prophecy. 'The Rajput Legacy' transforms into a quest to fulfill the prophecy, leading Rani Meher through treacherous landscapes and confrontations with those who seek to thwart destiny.", 'lang': 'en', 'createdAt': '2024-01-07T16:13:16.270Z', 'updatedAt': '2024-01-07T16:13:16.270Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'WyPmZoBLZ4K9anDQ', 'hashRootId': 'WyPmZoBLZ4K9anDQ', 'isExtraTwist': False, 'closestHashRootId': 'WyPmZoBLZ4K9anDQ'}
# Second Twist created successfully: {'hashId': 'LD7mdo0pOPopjE95', 'authorId': '1932', 'title': 'Clash of Legacies', 'body': "As Rani Meher progresses on the quest, she encounters a rival Rajput clan with a conflicting interpretation of the prophecy. 'The Rajput Legacy' becomes a tale of rivalries, alliances, and the ultimate battle for the preservation of Rajput heritage.", 'lang': 'en', 'createdAt': '2024-01-07T16:13:17.679Z', 'updatedAt': '2024-01-07T16:13:17.679Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'OAMNrJNLpEw4Wpnv', 'hashRootId': 'WyPmZoBLZ4K9anDQ', 'isExtraTwist': False, 'closestHashRootId': 'WyPmZoBLZ4K9anDQ'}
