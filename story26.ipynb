# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data for "The Galactic"
new_story_data = {
    'title': 'The Galactic',
    'body': (
        "In the far reaches of the cosmos, 'The Galactic Nexus' unfolds. Captain Aria, an intrepid explorer, discovers a cosmic anomaly "
        "that serves as a gateway to uncharted galaxies. As Aria ventures into this nexus, she encounters fantastical realms, mythical creatures, "
        "and the convergence of science and magic.\n\n"
        "Her journey becomes an adventure through the boundless expanse of the universe, where the lines between reality and fiction blur."
    ),
    'tags': ['Adventure', 'Fantasy', 'Fiction', 'Science'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating new twists
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "As Captain Aria delves deeper into the Galactic Nexus, she encounters a celestial being with the ability to manipulate reality. "
        "This being, known as Astralweaver, presents Aria with a choice — to use the nexus for the betterment of civilizations or to safeguard "
        "its secrets from those who seek to exploit its power.\n\n"
        "The Galactic Nexus transforms into a moral dilemma, testing Aria's convictions and defining the legacy she leaves in the cosmos."
    ),
    'title': 'Astralweaver\'s Choice',
    'tags': ['Celestial Being', 'Reality Manipulation', 'Moral Dilemma', 'Cosmic Legacy'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "Within the Galactic Nexus, Captain Aria discovers ancient archives containing the forgotten histories of extraterrestrial civilizations. "
        "These histories reveal an imminent cosmic threat that could engulf the entire galaxy. Aria faces a race against time, torn between revealing "
        "the impending danger to the galaxy or preserving the delicate balance of cosmic ignorance.\n\n"
        "The Galactic Nexus becomes a battleground of knowledge, and Aria must decide the fate of the galaxy based on the revelations from the archives."
    ),
    'title': 'Cosmic Archives Unveiled',
    'tags': ['Ancient Histories', 'Cosmic Threat', 'Race Against Time', 'Galactic Fate'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "In the climactic moments within the Galactic Nexus, Captain Aria encounters a mysterious cosmic entity that transcends the fabric of reality. "
        "This entity, known as Nexus Guardian, imparts ancient wisdom and offers Aria a chance to become a cosmic guardian. Aria must decide whether to "
        "embrace her newfound role, becoming a protector of the cosmic balance, or to return to her explorative roots.\n\n"
        "The Galactic Nexus concludes with Aria's ultimate choice, shaping the destiny of the cosmos."
    ),
    'title': 'Nexus Guardian\'s Revelation',
    'tags': ['Cosmic Entity', 'Guardian Role', 'Ancient Wisdom', 'Cosmic Destiny'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'DylLQoL1d9J9jdkY', 'authorId': '1932', 'title': 'The Galactic', 'body': "In the far reaches of the cosmos, 'The Galactic Nexus' unfolds. Captain Aria, an intrepid explorer, discovers a cosmic anomaly that serves as a gateway to uncharted galaxies. As Aria ventures into this nexus, she encounters fantastical realms, mythical creatures, and the convergence of science and magic.\n\nHer journey becomes an adventure through the boundless expanse of the universe, where the lines between reality and fiction blur.", 'lang': 'en', 'createdAt': '2024-01-26T09:49:56.977Z', 'updatedAt': '2024-01-26T09:49:56.977Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# ...
