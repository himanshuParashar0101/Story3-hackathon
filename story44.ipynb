# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'The Celestial Nexus',
    'body': (
        "In the vast expanse of the cosmos, a cosmic phenomenon known as the Celestial Nexus emerges. Astronomers and space explorers from "
        "across the universe converge to witness this unprecedented event. The Celestial Nexus becomes a focal point of cosmic energies, "
        "and those who venture into its depths are said to gain profound insights into the mysteries of the universe."
    ),
    'tags': ['Cosmic Phenomenon', 'Space Exploration', 'Celestial Energies', 'Mysteries of the Universe'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "As space explorers approach the Celestial Nexus, they encounter a sentient cosmic entity that communicates through mesmerizing light patterns. "
        "The entity imparts ancient knowledge, revealing the interconnectedness of galaxies and the cosmic web that binds all celestial bodies. "
        "The Celestial Nexus transforms into a cosmic library, where seekers gain access to the wisdom of the cosmos."
    ),
    'title': 'Wisdom of Cosmic Entities',
    'tags': ['Sentient Cosmic Entity', 'Ancient Knowledge', 'Interconnected Galaxies', 'Cosmic Library'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "Deep within the Celestial Nexus, explorers discover portals leading to parallel dimensions. Each dimension harbors unique challenges and wonders, "
        "testing the courage and adaptability of those who dare to traverse them. The Celestial Nexus becomes a gateway to the multiverse, where the boundaries "
        "between realities blur."
    ),
    'title': 'Portals of Parallel Dimensions',
    'tags': ['Parallel Dimensions', 'Multiverse', 'Dimensional Challenges', 'Gateway to the Cosmos'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "As the Celestial Nexus reaches its zenith, a cosmic convergence occurs. Celestial beings from distant galaxies manifest, "
        "bringing a message of unity and harmony. The Celestial Nexus becomes a symbol of cosmic oneness, where diverse civilizations join "
        "to celebrate the interconnected tapestry of the universe."
    ),
    'title': 'Harmony of Cosmic Convergence',
    'tags': ['Cosmic Beings', 'Unity', 'Harmony', 'Interconnected Tapestry'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'WyPmZoBd9bK9anDQ', 'authorId': '1932', 'title': 'The Celestial Nexus', 'body': 'In the vast expanse of the cosmos, a cosmic phenomenon known as the Celestial Nexus emerges. Astronomers and space explorers from across the universe converge to witness this unprecedented event. The Celestial Nexus becomes a focal point of cosmic energies, and those who venture into its depths are said to gain profound insights into the mysteries of the universe.', 'lang': 'en', 'createdAt': '2024-01-26T11:04:00.180Z', 'updatedAt': '2024-01-26T11:04:00.180Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# ...
