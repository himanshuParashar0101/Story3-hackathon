# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'The Celestial Convergence',
    'body': (
        "In a distant galaxy, the Celestial Convergence is foretold—a cosmic event that occurs once in a millennium. As the celestial bodies align, "
        "an ancient prophecy is set into motion. Captain Astra, an intrepid explorer, embarks on a journey to witness the convergence and unravel its "
        "mysteries. The fabric of space and time begins to ripple with celestial energy, revealing portals to unexplored dimensions."
    ),
    'tags': ['Celestial Convergence', 'Cosmic Event', 'Ancient Prophecy', 'Interdimensional Portals'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "As Captain Astra witnesses the Celestial Convergence, a mysterious cosmic entity known as the Starweaver manifests. The Starweaver, "
        "woven from stardust and cosmic threads, imparts ancient knowledge about the interconnectedness of galaxies and the role of celestial beings "
        "in maintaining cosmic balance."
    ),
    'title': 'Harmony of Stars',
    'tags': ['Starweaver', 'Cosmic Entity', 'Interconnected Galaxies', 'Celestial Balance'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "Amidst the Celestial Convergence, Captain Astra encounters a cosmic anomaly—a gateway to a realm where time flows differently. "
        "Navigating this temporal flux, Astra glimpses alternate timelines and faces decisions that echo through the corridors of time."
    ),
    'title': 'Temporal Nexus',
    'tags': ['Cosmic Anomaly', 'Temporal Flux', 'Alternate Timelines', 'Echoes of Decisions'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "In the culmination of the Celestial Convergence, Captain Astra faces a cosmic dilemma. The convergence unveils a cosmic artifact, the "
        "'Nebula Scepter,' capable of shaping the fabric of reality. Astra must decide whether to wield the scepter's power responsibly or guard "
        "against the temptation to reshape the cosmos."
    ),
    'title': 'Nebulas Choice',
    'tags': ['Cosmic Dilemma', 'Nebula Scepter', 'Reality Shaping', 'Cosmic Temptation'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'j1NX9oXOVdwkrZ7x', 'authorId': '1932', 'title': 'The Celestial Convergence', 'body': 'In a distant galaxy, the Celestial Convergence is foretold—a cosmic event that occurs once in a millennium. As the celestial bodies align, an ancient prophecy is set into motion. Captain Astra, an intrepid explorer, embarks on a journey to witness the convergence and unravel its mysteries. The fabric of space and time begins to ripple with celestial energy, revealing portals to unexplored dimensions.', 'lang': 'en', 'createdAt': '2024-01-26T11:04:17.032Z', 'updatedAt': '2024-01-26T11:04:17.032Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# ...
