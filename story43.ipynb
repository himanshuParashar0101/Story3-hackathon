# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'The Enchanted Odyssey',
    'body': (
        "In the heart of an enchanted realm, Eli, a young wanderer, discovers a hidden gateway to mystical dimensions. "
        "As Eli steps through the portal, an ancient prophecy unfolds. The Enchanted Odyssey becomes a journey to unlock magical "
        "secrets, face mythical beings, and restore balance to the enchanted realms."
    ),
    'tags': ['Enchanted Realm', 'Magical Dimensions', 'Ancient Prophecy', 'Mythical Beings'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "In the heart of the enchanted odyssey, Eli discovers a hidden sanctuary where ancient magical beings reside. "
        "The beings, attuned to the rhythms of the cosmos, offer Eli the chance to unlock dormant magical abilities. The odyssey transforms "
        "into a magical training, where Eli learns to wield elemental forces and harmonize with the mystical energies of the enchanted realms."
    ),
    'title': 'Harmony of Elemental Magic',
    'tags': ['Hidden Sanctuary', 'Magical Beings', 'Elemental Magic', 'Cosmic Harmonization'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "As Eli delves deeper into the enchanted realms, a celestial guardian challenges their newfound magical abilities. "
        "Eli must prove their worth through a series of mystical trials. The Enchanted Odyssey transforms into a heroic quest, where Eli "
        "confronts mythical creatures and unlocks the true potential of their magical powers."
    ),
    'title': 'Trials of Celestial Guardians',
    'tags': ['Celestial Guardian', 'Mystical Trials', 'Heroic Quest', 'Magical Powers'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "In the climactic finale of the Enchanted Odyssey, Eli faces a choice that could reshape the destiny of the enchanted realms. "
        "A cosmic artifact, hidden within the mystical dimensions, holds the power to either restore balance or plunge the realms into chaos. "
        "Eli's journey becomes a test of courage and wisdom, as they navigate the complexities of destiny and make a choice that echoes through the cosmos."
    ),
    'title': 'Echoes of Cosmic Destiny',
    'tags': ['Cosmic Artifact', 'Destiny', 'Choice', 'Enchanted Realms'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'VRplZKlL40KN4kvx', 'authorId': '1932', 'title': 'The Enchanted Odyssey', 'body': 'In the heart of an enchanted realm, Eli, a young wanderer, discovers a hidden gateway to mystical dimensions. As Eli steps through the portal, an ancient prophecy unfolds. The Enchanted Odyssey becomes a journey to unlock magical secrets, face mythical beings, and restore balance to the enchanted realms.', 'lang': 'en', 'createdAt': '2024-01-26T11:03:54.051Z', 'updatedAt': '2024-01-26T11:03:54.051Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# First Twist created successfully: {'hashId': '1nNYjK7lrrwd697b', 'authorId': '1932', 'title': 'Harmony of Elemental Magic', 'body': 'In the heart of the enchanted odyssey, Eli discovers a hidden sanctuary where ancient magical beings reside. The beings, attuned to the rhythms of the cosmos, offer Eli the chance to unlock dormant magical abilities. The odyssey transforms into a magical training, where Eli learns to wield elemental forces and harmonize with the mystical energies of the enchanted realms.', 'lang': 'en', 'createdAt': '2024-01-26T11:03:56.461Z', 'updatedAt': '2024-01-26T11:03:56.461Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'VRplZKlL40KN4kvx', 'hashRootId': 'VRplZKlL40KN4kvx', 'isExtraTwist': False, 'closestHashRootId': 'VRplZKlL40KN4kvx'}
# Second Twist created successfully: {'hashId': '51zRAKzL4yoDBaWe', 'authorId': '1932', 'title': 'Trials of Celestial Guardians', 'body': 'As Eli delves deeper into the enchanted realms, a celestial guardian challenges their newfound magical abilities. Eli must prove their worth through a series of mystical trials. The Enchanted Odyssey transforms into a heroic quest, where Eli confronts mythical creatures and unlocks the true potential of their magical powers.', 'lang': 'en', 'createdAt': '2024-01-26T11:03:57.547Z', 'updatedAt': '2024-01-26T11:03:57.547Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': '1nNYjK7lrrwd697b', 'hashRootId': 'VRplZKlL40KN4kvx', 'isExtraTwist': False, 'closestHashRootId': 'VRplZKlL40KN4kvx'}
# Third Twist created successfully: {'hashId': 'nV6mjKEZz6wEXx9B', 'authorId': '1932', 'title': 'Echoes of Cosmic Destiny', 'body': "In the climactic finale of the Enchanted Odyssey, Eli faces a choice that could reshape the destiny of the enchanted realms. A cosmic artifact, hidden within the mystical dimensions, holds the power to either restore balance or plunge the realms into chaos. Eli's journey becomes a test of courage and wisdom, as they navigate the complexities of destiny and make a choice that echoes through the cosmos.", 'lang': 'en', 'createdAt': '2024-01-26T11:03:59.008Z', 'updatedAt': '2024-01-26T11:03:59.008Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': '51zRAKzL4yoDBaWe', 'hashRootId': 'VRplZKlL40KN4kvx', 'isExtraTwist': False, 'closestHashRootId': 'VRplZKlL40KN4kvx'}
