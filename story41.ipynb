# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'The Enchanted Odyssey',
    'body': (
        "In the heart of the enchanted odyssey, Eli discovers a hidden sanctuary where ancient magical beings reside. "
        "The beings, attuned to the rhythms of the cosmos, offer Eli the chance to unlock dormant magical abilities. "
        "The odyssey transforms into a magical training, where Eli learns to wield elemental forces and harmonize with "
        "the mystical energies of the enchanted realms."
    ),
    'tags': ['Enchanted Odyssey', 'Hidden Sanctuary', 'Magical Beings', 'Elemental Magic'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "As Eli explores the hidden sanctuary, ancient scrolls reveal the secrets of elemental magic. Eli discovers the "
        "art of manipulating fire, water, earth, and air. The enchanted odyssey becomes a journey of self-discovery and "
        "mastery over the elemental forces that shape the magical realms."
    ),
    'title': 'Mysteries of Elemental Magic',
    'tags': ['Ancient Scrolls', 'Elemental Magic', 'Self-Discovery', 'Magical Realms'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "In the heart of the enchanted odyssey, Eli stumbles upon a cosmic anomaly that pulsates with mystical energies. "
        "The anomaly offers a choice: to embrace the untamed chaos or channel its power to restore balance to the magical realms. "
        "Eli faces the dilemma of harnessing raw magic for the greater good or succumbing to the allure of unchecked power."
    ),
    'title': 'Dilemma of Cosmic Energies',
    'tags': ['Cosmic Anomaly', 'Mystical Energies', 'Balance', 'Unchecked Power'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "As Eli delves deeper into the enchanted odyssey, a mystical oracle reveals a prophecy foretelling the convergence "
        "of magical realms. Eli must embark on a quest to fulfill the prophecy, navigating treacherous paths and facing formidable "
        "challenges. The odyssey becomes a race against time to unite the magical realms and avert a catastrophe."
    ),
    'title': 'Prophecy of Convergence',
    'tags': ['Mystical Oracle', 'Prophecy', 'Quest', 'Magical Realms'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'lyme0og6kpw9BY1k', 'authorId': '1932', 'title': 'The Enchanted Odyssey', 'body': 'In the heart of the enchanted odyssey, Eli discovers a hidden sanctuary where ancient magical beings reside. The beings, attuned to the rhythms of the cosmos, offer Eli the chance to unlock dormant magical abilities. The odyssey transforms into a magical training, where Eli learns to wield elemental forces and harmonize with the mystical energies of the enchanted realms.', 'lang': 'en', 'createdAt': '2024-01-26T11:03:35.411Z', 'updatedAt': '2024-01-26T11:03:35.411Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# ...
