# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'The Enchanted Odyssey',
    'body': (
        "Embark on an enchanted odyssey through realms of magic and mystery. Eli, a curious wanderer, discovers a hidden portal "
        "that leads to otherworldly dimensions filled with mythical creatures and ancient wonders."
    ),
    'tags': ['Enchanted Odyssey', 'Magic', 'Mystery', 'Mythical Creatures'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "In the heart of the enchanted odyssey, Eli discovers a hidden sanctuary where ancient magical beings reside. "
        "The beings, attuned to the rhythms of the cosmos, offer Eli the chance to unlock dormant magical abilities. "
        "The odyssey transforms into a magical training, where Eli learns to wield elemental forces and harmonize with "
        "the mystical energies of the enchanted realms."
    ),
    'title': 'Harmony of Elemental Magic',
    'tags': ['Hidden Sanctuary', 'Magical Beings', 'Elemental Magic', 'Cosmic Harmonization'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "As Eli delves deeper into the enchanted realms, a mysterious prophecy unfolds. The prophecy hints at a cosmic event "
        "that could either bring prosperity or chaos to the realms. Eli must decipher the prophecy and make choices that shape "
        "the destiny of the enchanted odyssey."
    ),
    'title': 'Mystic Prophecy Unveiled',
    'tags': ['Mystic Prophecy', 'Cosmic Event', 'Destiny Shaping', 'Enchanted Realms'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "In the midst of the enchanted odyssey, Eli encounters a cosmic enigma that challenges the very fabric of reality. "
        "The enigma holds the key to unlocking the ultimate potential of the enchanted realms. Eli faces the dilemma of either "
        "preserving the realms' delicate balance or unlocking the untold possibilities within the cosmic enigma."
    ),
    'title': 'Cosmic Enigma Unleashed',
    'tags': ['Cosmic Enigma', 'Reality Challenge', 'Realm Balance', 'Untold Possibilities'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'WyPmZoBdVbK9anDQ', 'authorId': '1932', 'title': 'The Enchanted Odyssey', 'body': 'Embark on an enchanted odyssey through realms of magic and mystery. Eli, a curious wanderer, discovers a hidden portal that leads to otherworldly dimensions filled with mythical creatures and ancient wonders.', 'lang': 'en', 'createdAt': '2024-01-26T10:36:17.358Z', 'updatedAt': '2024-01-26T10:36:17.358Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# First Twist created successfully: {'hashId': 'OAMNrJNrBNJ4Wpnv', 'authorId': '1932', 'title': 'Harmony of Elemental Magic', 'body': 'In the heart of the enchanted odyssey, Eli discovers a hidden sanctuary where ancient magical beings reside. The beings, attuned to the rhythms of the cosmos, offer Eli the chance to unlock dormant magical abilities. The odyssey transforms into a magical training, where Eli learns to wield elemental forces and harmonize with the mystical energies of the enchanted realms.', 'lang': 'en', 'createdAt': '2024-01-26T10:36:19.475Z', 'updatedAt': '2024-01-26T10:36:19.475Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'WyPmZoBdVbK9anDQ', 'hashRootId': 'WyPmZoBdVbK9anDQ', 'isExtraTwist': False, 'closestHashRootId': 'WyPmZoBdVbK9anDQ'}
# Second Twist created successfully: {'hashId': 'LD7mdo02zdKpjE95', 'authorId': '1932', 'title': 'Mystic Prophecy Unveiled', 'body': 'As Eli delves deeper into the enchanted realms, a mysterious prophecy unfolds. The prophecy hints at a cosmic event that could either bring prosperity or chaos to the realms. Eli must decipher the prophecy and make choices that shape the destiny of the enchanted odyssey.', 'lang': 'en', 'createdAt': '2024-01-26T10:36:20.873Z', 'updatedAt': '2024-01-26T10:36:20.873Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'OAMNrJNrBNJ4Wpnv', 'hashRootId': 'WyPmZoBdVbK9anDQ', 'isExtraTwist': False, 'closestHashRootId': 'WyPmZoBdVbK9anDQ'}
# Third Twist created successfully: {'hashId': '3qNkYok5N5KQPOEM', 'authorId': '1932', 'title': 'Cosmic Enigma Unleashed', 'body': "In the midst of the enchanted odyssey, Eli encounters a cosmic enigma that challenges the very fabric of reality. The enigma holds the key to unlocking the ultimate potential of the enchanted realms. Eli faces the dilemma of either preserving the realms' delicate balance or unlocking the untold possibilities within the cosmic enigma.", 'lang': 'en', 'createdAt': '2024-01-26T10:36:22.743Z', 'updatedAt': '2024-01-26T10:36:22.743Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'LD7mdo02zdKpjE95', 'hashRootId': 'WyPmZoBdVbK9anDQ', 'isExtraTwist': False, 'closestHashRootId': 'WyPmZoBdVbK9anDQ'}
