# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',# Replace with your actual API key
    }

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data for Story 23
new_story_data = {
    'title': 'Mystic Sands of Rishikesh',
    'body': (
        "In the serene town of Rishikesh, 'Mystic Sands of Rishikesh' unfolds the tale of Arjun, a seeker drawn to the mystic energies "
        "emanating from the Ganges. As he explores the sacred ghats and hidden caves, Arjun discovers an ancient manuscript revealing "
        "the lost art of harnessing spiritual energies.\n\n"
        "His spiritual journey becomes a quest to revive the ancient wisdom of Rishikesh and unlock the transformative power of the mystic sands."
    ),
    'tags': ['Rishikesh', 'Spiritual Journey', 'Mystic Energies', 'Ancient Wisdom'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# First twist data for Story 23
first_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "In the silent meditation by the Ganges, Arjun connects with ancient sages who impart the knowledge of unlocking spiritual "
        "energies. 'Mystic Sands of Rishikesh' transforms into a spiritual odyssey guided by the whispers of the ancient sages."
    ),
    'title': 'Whispers of Sages',
    'tags': ['Meditation', 'Ancient Sages', 'Spiritual Odyssey', 'Guidance'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=first_twist_data)

if response.status_code == 201:
    first_twist_info = response.json()
    print(f'First Twist created successfully: {first_twist_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Second twist data for Story 23
second_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': first_twist_info['hashId'],
    'body': (
        "During the festival of colors, Holi, the mystic sands of Rishikesh come alive with vibrant hues. 'Mystic Sands of Rishikesh' "
        "becomes a celebration of spiritual enlightenment and the harmonious blending of ancient wisdom with the colors of Holi."
    ),
    'title': 'Holi Enlightenment',
    'tags': ['Holi Celebration', 'Spiritual Enlightenment', 'Mystic Sands', 'Harmonious Blending'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=second_twist_data)

if response.status_code == 201:
    second_twist_info = response.json()
    print(f'Second Twist created successfully: {second_twist_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'AVPONJeY4zJyvxqX', 'authorId': '1932', 'title': 'Mystic Sands of Rishikesh', 'body': "In the serene town of Rishikesh, 'Mystic Sands of Rishikesh' unfolds the tale of Arjun, a seeker drawn to the mystic energies emanating from the Ganges. As he explores the sacred ghats and hidden caves, Arjun discovers an ancient manuscript revealing the lost art of harnessing spiritual energies.\n\nHis spiritual journey becomes a quest to revive the ancient wisdom of Rishikesh and unlock the transformative power of the mystic sands.", 'lang': 'en', 'createdAt': '2024-01-07T16:56:12.060Z', 'updatedAt': '2024-01-07T16:56:12.060Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# First Twist created successfully: {'hashId': 'd4NXzJDLxYJWe285', 'authorId': '1932', 'title': 'Whispers of Sages', 'body': "In the silent meditation by the Ganges, Arjun connects with ancient sages who impart the knowledge of unlocking spiritual energies. 'Mystic Sands of Rishikesh' transforms into a spiritual odyssey guided by the whispers of the ancient sages.", 'lang': 'en', 'createdAt': '2024-01-07T16:56:14.220Z', 'updatedAt': '2024-01-07T16:56:14.220Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'AVPONJeY4zJyvxqX', 'hashRootId': 'AVPONJeY4zJyvxqX', 'isExtraTwist': False, 'closestHashRootId': 'AVPONJeY4zJyvxqX'}
# Second Twist created successfully: {'hashId': 'ng6eXwmx7kKdbMLZ', 'authorId': '1932', 'title': 'Holi Enlightenment', 'body': "During the festival of colors, Holi, the mystic sands of Rishikesh come alive with vibrant hues. 'Mystic Sands of Rishikesh' becomes a celebration of spiritual enlightenment and the harmonious blending of ancient wisdom with the colors of Holi.", 'lang': 'en', 'createdAt': '2024-01-07T16:56:15.637Z', 'updatedAt': '2024-01-07T16:56:15.637Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'd4NXzJDLxYJWe285', 'hashRootId': 'AVPONJeY4zJyvxqX', 'isExtraTwist': False, 'closestHashRootId': 'AVPONJeY4zJyvxqX'}
