# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'The Celestial Chronicles',
    'body': (
        "In the vast expanse of the cosmos, a celestial navigator named Seraphina embarks on a journey across the "
        "Celestial Chronicles. Guided by ancient star maps and a sentient cosmic compass, Seraphina voyages through "
        "unexplored galaxies, uncovering the mysteries woven into the fabric of the celestial tapestry."
    ),
    'tags': ['Cosmic Odyssey', 'Celestial Navigator', 'Ancient Star Maps', 'Cosmic Compass'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "As Seraphina delves deeper into the cosmic expanse, she encounters a sentient star cluster with the ability "
        "to communicate through ethereal vibrations. This celestial entity imparts ancient wisdom, revealing the interconnected "
        "nature of galaxies. Seraphina learns that each twinkle of a star is a cosmic language, and each galaxy is a verse in the "
        "poetry of the universe."
    ),
    'title': 'Harmony of Celestial Vibrations',
    'tags': ['Sentient Star Cluster', 'Cosmic Language', 'Celestial Symphony', 'Hidden Realms'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "In the heart of the Celestial Chronicles, Seraphina stumbles upon a cosmic anomaly that threatens to unravel "
        "the stability of the celestial tapestry. The anomaly pulsates with unpredictable cosmic fluctuations, creating rifts "
        "between dimensions. Seraphina faces a cosmic dilemma — whether to close the anomaly and restore balance or harness its power "
        "to explore uncharted realms."
    ),
    'title': 'Rifts of Destiny',
    'tags': ['Cosmic Anomaly', 'Celestial Stability', 'Cosmic Dilemma', 'Uncharted Realms'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "As the cosmic odyssey unfolds, Seraphina discovers an ancient prophecy foretelling the convergence of celestial forces. "
        "She must navigate the cosmic currents, facing celestial guardians and unlocking the dormant powers within her. The Celestial Chronicles "
        "become a quest to fulfill the prophecy and preserve the cosmic balance."
    ),
    'title': 'Prophecy of Celestial Convergence',
    'tags': ['Celestial Prophecy', 'Cosmic Forces', 'Celestial Guardians', 'Cosmic Balance'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'ng6eXwmL4MKdbMLZ', 'authorId': '1932', 'title': 'The Celestial Chronicles', 'body': 'In the vast expanse of the cosmos, a celestial navigator named Seraphina embarks on a journey across the Celestial Chronicles. Guided by ancient star maps and a sentient cosmic compass, Seraphina voyages through unexplored galaxies, uncovering the mysteries woven into the fabric of the celestial tapestry.', 'lang': 'en', 'createdAt': '2024-01-26T11:03:47.695Z', 'updatedAt': '2024-01-26T11:03:47.695Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# ...
