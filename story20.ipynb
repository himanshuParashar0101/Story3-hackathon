# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',# Replace with your actual API key
  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data for Story 19
new_story_data = {
    'title': 'Serenade of the Ganges',
    'body': (
        "Navigate the flowing currents of the Ganges in 'Serenade of the Ganges.' Meera, a young musician, discovers a mystical "
        "instrument that resonates with the spirit of the sacred river. As she plays melodic tunes, the Ganges responds, weaving "
        "a harmonious symphony that echoes through the temples and ghats.\n\n"
        "Meera's musical journey becomes a tribute to the Ganges, embracing the cultural and spiritual significance of the sacred river."
    ),
    'tags': ['Ganges', 'Music', 'Cultural Heritage', 'Spirituality'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# First twist data for Story 19
first_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "During a moonlit night on the ghats, Meera encounters a celestial being that imparts ancient melodies. 'Serenade of the Ganges' "
        "transforms into a celestial collaboration, blending earthly and ethereal notes in a symphony that transcends mortal realms."
    ),
    'title': 'Celestial Collaboration',
    'tags': ['Moonlit Night', 'Celestial Being', 'Ancient Melodies', 'Symphony'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=first_twist_data)

if response.status_code == 201:
    first_twist_info = response.json()
    print(f'First Twist created successfully: {first_twist_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Second twist data for Story 19
second_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': first_twist_info['hashId'],
    'body': (
        "In the heart of Varanasi, Meera discovers an ancient manuscript that reveals the sacred connection between music and spirituality. "
        "'Serenade of the Ganges' becomes a quest to preserve the divine harmony and pass on the musical traditions to future generations."
    ),
    'title': 'Harmony of the Ancients',
    'tags': ['Varanasi', 'Ancient Manuscript', 'Divine Harmony', 'Musical Traditions'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=second_twist_data)

if response.status_code == 201:
    second_twist_info = response.json()
    print(f'Second Twist created successfully: {second_twist_info}')
else:
     print(f'Error creating the second twist. Status code: {response.status_code}')
     print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'DylLQoLLORo9jdkY', 'authorId': '1932', 'title': 'Serenade of the Ganges', 'body': "Navigate the flowing currents of the Ganges in 'Serenade of the Ganges.' Meera, a young musician, discovers a mystical instrument that resonates with the spirit of the sacred river. As she plays melodic tunes, the Ganges responds, weaving a harmonious symphony that echoes through the temples and ghats.\n\nMeera's musical journey becomes a tribute to the Ganges, embracing the cultural and spiritual significance of the sacred river.", 'lang': 'en', 'createdAt': '2024-01-07T16:37:11.490Z', 'updatedAt': '2024-01-07T16:37:11.490Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# First Twist created successfully: {'hashId': 'rm8DeK5rbbw9zagq', 'authorId': '1932', 'title': 'Celestial Collaboration', 'body': "During a moonlit night on the ghats, Meera encounters a celestial being that imparts ancient melodies. 'Serenade of the Ganges' transforms into a celestial collaboration, blending earthly and ethereal notes in a symphony that transcends mortal realms.", 'lang': 'en', 'createdAt': '2024-01-07T16:37:13.867Z', 'updatedAt': '2024-01-07T16:37:13.867Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'DylLQoLLORo9jdkY', 'hashRootId': 'DylLQoLLORo9jdkY', 'isExtraTwist': False, 'closestHashRootId': 'DylLQoLLORo9jdkY'}
# Second Twist created successfully: {'hashId': 'jm64zJ31MnwYReW5', 'authorId': '1932', 'title': 'Harmony of the Ancients', 'body': "In the heart of Varanasi, Meera discovers an ancient manuscript that reveals the sacred connection between music and spirituality. 'Serenade of the Ganges' becomes a quest to preserve the divine harmony and pass on the musical traditions to future generations.", 'lang': 'en', 'createdAt': '2024-01-07T16:37:15.243Z', 'updatedAt': '2024-01-07T16:37:15.243Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'rm8DeK5rbbw9zagq', 'hashRootId': 'DylLQoLLORo9jdkY', 'isExtraTwist': False, 'closestHashRootId': 'DylLQoLLORo9jdkY'}
