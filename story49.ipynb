# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'The Ethereal Nexus',
    'body': (
        "In the mystical realm of ethereal energies, a young sorcerer named Elara discovers the existence of an ancient nexus. This nexus, hidden between dimensions, "
        "holds the key to harnessing the pure essence of magic. Elara embarks on a quest to unlock the secrets of the Ethereal Nexus and balance the forces of magic in "
        "the realms of existence."
    ),
    'tags': ['Magic', 'Ethereal Energies', 'Ancient Nexus', 'Sorcery'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "As Elara delves into the secrets of the Ethereal Nexus, she encounters a spectral guardian. This ethereal being imparts ancient knowledge, revealing the "
        "balance between light and shadow magic. Elara must choose whether to embrace the harmony of both or risk disrupting the delicate equilibrium."
    ),
    'title': 'Harmony of Shadows',
    'tags': ['Spectral Guardian', 'Ethereal Knowledge', 'Light and Shadow Magic', 'Harmony'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "Guided by the spectral guardian, Elara discovers a forbidden realm where the boundaries between magical elements blur. This realm poses a threat to the "
        "fabric of reality, and Elara faces a moral dilemma—to seal the realm or harness its power for the betterment of magic users."
    ),
    'title': 'Realm of Elemental Convergence',
    'tags': ['Forbidden Realm', 'Magical Elements', 'Reality Threat', 'Moral Dilemma'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "In the climactic revelation, Elara faces an ancient sorcerer who seeks to manipulate the Ethereal Nexus for dark purposes. The nexus's true power and the "
        "fate of magical realms hang in the balance as Elara confronts the sorcerer in a battle of magical prowess."
    ),
    'title': 'Confrontation of Arcane Destiny',
    'tags': ['Ancient Sorcerer', 'Dark Purposes', 'Ethereal Nexus Power', 'Magical Battle'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'Rb32VJY9YMJA50gY', 'authorId': '1932', 'title': 'The Ethereal Nexus', 'body': 'In the mystical realm of ethereal energies, a young sorcerer named Elara discovers the existence of an ancient nexus. This nexus, hidden between dimensions, holds the key to harnessing the pure essence of magic. Elara embarks on a quest to unlock the secrets of the Ethereal Nexus and balance the forces of magic in the realms of existence.', 'lang': 'en', 'createdAt': '2024-01-26T11:05:05.665Z', 'updatedAt': '2024-01-26T11:05:05.665Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# First Twist created successfully: {'hashId': 'axv48oyLQEwQ1rn6', 'authorId': '1932', 'title': 'Harmony of Shadows', 'body': 'As Elara delves into the secrets of the Ethereal Nexus, she encounters a spectral guardian. This ethereal being imparts ancient knowledge, revealing the balance between light and shadow magic. Elara must choose whether to embrace the harmony of both or risk disrupting the delicate equilibrium.', 'lang': 'en', 'createdAt': '2024-01-26T11:05:08.223Z', 'updatedAt': '2024-01-26T11:05:08.223Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'Rb32VJY9YMJA50gY', 'hashRootId': 'Rb32VJY9YMJA50gY', 'isExtraTwist': False, 'closestHashRootId': 'Rb32VJY9YMJA50gY'}
# Second Twist created successfully: {'hashId': 'adegAJ1ezlJOMbNl', 'authorId': '1932', 'title': 'Realm of Elemental Convergence', 'body': 'Guided by the spectral guardian, Elara discovers a forbidden realm where the boundaries between magical elements blur. This realm poses a threat to the fabric of reality, and Elara faces a moral dilemma—to seal the realm or harness its power for the betterment of magic users.', 'lang': 'en', 'createdAt': '2024-01-26T11:05:10.229Z', 'updatedAt': '2024-01-26T11:05:10.229Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'axv48oyLQEwQ1rn6', 'hashRootId': 'Rb32VJY9YMJA50gY', 'isExtraTwist': False, 'closestHashRootId': 'Rb32VJY9YMJA50gY'}
# Third Twist created successfully: {'hashId': 'klQ46KakxqoqVaE7', 'authorId': '1932', 'title': 'Confrontation of Arcane Destiny', 'body': "In the climactic revelation, Elara faces an ancient sorcerer who seeks to manipulate the Ethereal Nexus for dark purposes. The nexus's true power and the fate of magical realms hang in the balance as Elara confronts the sorcerer in a battle of magical prowess.", 'lang': 'en', 'createdAt': '2024-01-26T11:05:11.417Z', 'updatedAt': '2024-01-26T11:05:11.417Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'adegAJ1ezlJOMbNl', 'hashRootId': 'Rb32VJY9YMJA50gY', 'isExtraTwist': False, 'closestHashRootId': 'Rb32VJY9YMJA50gY'}
