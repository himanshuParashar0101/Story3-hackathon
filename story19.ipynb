# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',# Replace with your actual API key
  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data for Story 20
new_story_data = {
    'title': 'Echoes of Rajasthan',
    'body': (
        "Embark on a journey through the vibrant landscapes of Rajasthan in 'Echoes of Rajasthan.' Raj, a young artist, "
        "discovers a mystical canvas that captures the essence of the desert. As he paints, the colors come alive, revealing "
        "the stories of bygone kings, folk traditions, and the spirit of the Thar Desert.\n\n"
        "Raj's artistic odyssey becomes a tribute to the rich cultural tapestry of Rajasthan, echoing the tales of valor and "
        "resilience that resonate through the ages."
    ),
    'tags': ['Rajasthan', 'Art', 'Cultural Tapestry', 'Desert'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# First twist data for Story 20
first_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "In the heart of Jaipur, Raj encounters a mysterious art connoisseur who imparts ancient techniques. 'Echoes of Rajasthan' "
        "transforms into a fusion of contemporary and traditional art, capturing the dynamic spirit of the Pink City."
    ),
    'title': 'Artistry Unveiled',
    'tags': ['Jaipur', 'Art Connoisseur', 'Ancient Techniques', 'Contemporary Art'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=first_twist_data)

if response.status_code == 201:
    first_twist_info = response.json()
    print(f'First Twist created successfully: {first_twist_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Second twist data for Story 20
second_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': first_twist_info['hashId'],
    'body': (
        "Amidst the dunes of Jaisalmer, Raj discovers a hidden mural that depicts the untold stories of desert nomads. 'Echoes of Rajasthan' "
        "becomes a quest to preserve the vanishing heritage and celebrate the resilience of the people of the Thar."
    ),
    'title': 'Desert Chronicles',
    'tags': ['Jaisalmer', 'Hidden Mural', 'Desert Nomads', 'Heritage Preservation'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=second_twist_data)

if response.status_code == 201:
    second_twist_info = response.json()
    print(f'Second Twist created successfully: {second_twist_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
#   File <string>:83
#     print(f'Error response: {response.json()}')
#                                                ^
# IndentationError: unindent does not match any outer indentation level
