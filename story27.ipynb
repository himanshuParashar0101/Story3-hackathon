# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data for the similar topic
new_story_data = {
    'title': 'The Celestial Odyssey',
    'body': (
        "Embark on 'The Celestial Odyssey,' where Captain Orion explores the cosmic wonders beyond our galaxy. Guided by ancient star maps "
        "and equipped with an interstellar vessel, Orion ventures into uncharted realms. Each star system holds secrets of civilizations long forgotten, "
        "and each nebula conceals cosmic wonders beyond imagination.\n\n"
        "As Orion travels deeper into the cosmos, encounters with celestial beings, cosmic anomalies, and interstellar phenomena unfold. The fabric "
        "of space and time becomes a tapestry woven with the threads of destiny. The odyssey is not merely a quest for exploration but a revelation of "
        "the interconnectedness of the universe."
    ),
    'tags': ['Adventure', 'Fantasy', 'Fiction', 'Science'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating new twists
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "As Captain Orion delves deeper into the celestial expanse, a sentient star cluster imparts ancient wisdom. The Harmony Keeper reveals "
        "that each twinkle of a star is a cosmic language, and each galaxy is a verse in the poetry of the universe. Orion's spacecraft transforms into "
        "a cosmic instrument, composing symphonies that resonate across galaxies, awakening dormant celestial beings and unlocking hidden realms."
    ),
    'title': 'Harmony of Celestial Vibrations',
    'tags': ['Sentient Star Cluster', 'Cosmic Language', 'Celestial Symphony', 'Hidden Realms'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "In the heart of a distant galaxy, Captain Orion confronts the enigma of existence itself. Through wormholes and across event horizons, "
        "Orion discovers a cosmic symphony resonating through the cosmos. The odyssey becomes a transformative experience, blurring the boundaries "
        "between the explorer and the explored."
    ),
    'title': 'The Enigma of Existence',
    'tags': ['Distant Galaxy', 'Wormholes', 'Cosmic Symphony', 'Transformative Experience'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "As the Celestial Odyssey reaches its climax, Captain Orion discovers a cosmic anomaly that threatens to disrupt the stability of the multiverse. "
        "The anomaly pulses with unpredictable quantum fluctuations, creating rifts between dimensions. Orion faces a moral dilemma — whether to close the "
        "anomaly and restore balance or harness its power to explore uncharted realms."
    ),
    'title': 'Rifts of Quantum Destiny',
    'tags': ['Cosmic Anomaly', 'Multiverse Stability', 'Moral Dilemma', 'Quantum Fluctuations'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# Error creating a new story. Status code: 400
# Error response: {'statusCode': 400, 'requestId': '5e144aa5a4e6878532bd42837b743c13', 'message': 'Token decoding error', 'error': 'Bad Request'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 45
#      41 twists_url = f'{base_url}/twists'
#      43 # Twist 1 data
#      44 twist1_data = {
# ---> 45     'hashId': selected_story_hash,
#      46     'hashParentId': selected_story_hash,
#      47     'body': (
#      48         "As Captain Orion delves deeper into the celestial expanse, a sentient star cluster imparts ancient wisdom. The Harmony Keeper reveals "
#      49         "that each twinkle of a star is a cosmic language, and each galaxy is a verse in the poetry of the universe. Orion's spacecraft transforms into "
# ...
