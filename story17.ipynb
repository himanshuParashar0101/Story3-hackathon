# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data for Story 17
new_story_data = {
    'title': 'Whispers of Varanasi',
    'body': (
        "Embark on a mystical journey through the ancient city in 'Whispers of Varanasi.' In the spiritual heart of India, Varanasi's "
        "sacred ghats tell tales of profound spirituality and cultural richness. The story follows Aarav, a young poet, as he explores "
        "the hidden corners of Varanasi, seeking inspiration from the ethereal whispers of the Ganges.\n\n"
        "As Aarav delves deeper into the spiritual tapestry of Varanasi, the city becomes a muse for his poetic endeavors, and the ghats "
        "reveal secrets that intertwine with the essence of life itself."
    ),
    'tags': ['Varanasi', 'Spirituality', 'Ganges', 'Cultural Richness'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# First twist data for Story 17
first_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "In the serene alleys of Varanasi, Aarav encounters a mystical figure who imparts ancient wisdom. 'Whispers of Varanasi' "
        "transforms into a spiritual quest as Aarav learns about the interconnectedness of life and the timeless nature of Varanasi's legacy."
    ),
    'title': 'Sage  Revelation',
    'tags': ['Mystical Encounter', 'Ancient Wisdom', 'Spiritual Quest', 'Interconnectedness'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=first_twist_data)

if response.status_code == 201:
    first_twist_info = response.json()
    print(f'First Twist created successfully: {first_twist_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Second twist data for Story 17
second_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': first_twist_info['hashId'],
    'body': (
        "As Aarav continues his exploration, he stumbles upon an ancient manuscript that holds the forgotten stories of Varanasi. 'Whispers of Varanasi' "
        "becomes a journey through time as Aarav unravels the tales woven into the city's cultural fabric and becomes a custodian of its enduring legacy."
    ),
    'title': 'Chronicles of Time',
    'tags': ['Ancient Manuscript', 'Timeless Stories', 'Journey Through Time', 'Custodian of Legacy'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=second_twist_data)

if response.status_code == 201:
    second_twist_info = response.json()
    print(f'Second Twist created successfully: {second_twist_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'Wk7YNJ6nP1Jd6DRb', 'authorId': '1932', 'title': 'Whispers of Varanasi', 'body': "Embark on a mystical journey through the ancient city in 'Whispers of Varanasi.' In the spiritual heart of India, Varanasi's sacred ghats tell tales of profound spirituality and cultural richness. The story follows Aarav, a young poet, as he explores the hidden corners of Varanasi, seeking inspiration from the ethereal whispers of the Ganges.\n\nAs Aarav delves deeper into the spiritual tapestry of Varanasi, the city becomes a muse for his poetic endeavors, and the ghats reveal secrets that intertwine with the essence of life itself.", 'lang': 'en', 'createdAt': '2024-01-07T16:23:55.917Z', 'updatedAt': '2024-01-07T16:23:55.917Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# ...
