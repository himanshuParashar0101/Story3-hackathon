# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'The Enchanted Labyrinth',
    'body': (
        "In a mystical realm, a brave adventurer named Aria discovers an ancient labyrinth shrouded in enchantment. "
        "Legends speak of a hidden artifact at its heart that grants the power to traverse between worlds."
    ),
    'tags': ['Adventure', 'Mystery', 'Enchantment', 'Realm'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "As Aria delves deeper into the labyrinth, she encounters mystical guardians that challenge her with riddles. "
        "Solving these riddles unlocks ancient pathways, revealing the labyrinth's true purpose and the artifact's significance."
    ),
    'title': 'Riddles of the Guardians',
    'tags': ['Mystical Guardians', 'Riddles', 'Ancient Pathways', 'Artifact Significance'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "In the heart of the enchanted labyrinth, Aria discovers a sentient crystal that resonates with her inner magic. "
        "The crystal offers guidance on navigating the labyrinth's illusions and warns of the trials that lie ahead."
    ),
    'title': 'Resonance of the Crystal',
    'tags': ['Sentient Crystal', 'Enchanted Labyrinth', 'Inner Magic', 'Labyrinths Illusions'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "As Aria reaches the heart of the labyrinth, she faces a choice: use the artifact's power for the greater good or succumb "
        "to its tempting allure. The enchanted labyrinth becomes a test of Aria's character and her ability to resist the forces of temptation."
    ),
    'title': 'Trial of Temptation',
    'tags': ['Heart of the Labyrinth', 'Artifacts Power', 'Greater Good', 'Forces of Temptation'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'Nzy19JpLYZJePgXv', 'authorId': '1932', 'title': 'The Enchanted Labyrinth', 'body': 'In a mystical realm, a brave adventurer named Aria discovers an ancient labyrinth shrouded in enchantment. Legends speak of a hidden artifact at its heart that grants the power to traverse between worlds.', 'lang': 'en', 'createdAt': '2024-01-26T10:27:47.992Z', 'updatedAt': '2024-01-26T10:27:47.992Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# First Twist created successfully: {'hashId': 'QNePGwQgkEJLyBnD', 'authorId': '1932', 'title': 'Riddles of the Guardians', 'body': "As Aria delves deeper into the labyrinth, she encounters mystical guardians that challenge her with riddles. Solving these riddles unlocks ancient pathways, revealing the labyrinth's true purpose and the artifact's significance.", 'lang': 'en', 'createdAt': '2024-01-26T10:27:50.356Z', 'updatedAt': '2024-01-26T10:27:50.356Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'Nzy19JpLYZJePgXv', 'hashRootId': 'Nzy19JpLYZJePgXv', 'isExtraTwist': False, 'closestHashRootId': 'Nzy19JpLYZJePgXv'}
# Second Twist created successfully: {'hashId': 'axv48oyLgEwQ1rn6', 'authorId': '1932', 'title': 'Resonance of the Crystal', 'body': "In the heart of the enchanted labyrinth, Aria discovers a sentient crystal that resonates with her inner magic. The crystal offers guidance on navigating the labyrinth's illusions and warns of the trials that lie ahead.", 'lang': 'en', 'createdAt': '2024-01-26T10:27:51.478Z', 'updatedAt': '2024-01-26T10:27:51.478Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'QNePGwQgkEJLyBnD', 'hashRootId': 'Nzy19JpLYZJePgXv', 'isExtraTwist': False, 'closestHashRootId': 'Nzy19JpLYZJePgXv'}
# Third Twist created successfully: {'hashId': 'adegAJ1eElJOMbNl', 'authorId': '1932', 'title': 'Trial of Temptation', 'body': "As Aria reaches the heart of the labyrinth, she faces a choice: use the artifact's power for the greater good or succumb to its tempting allure. The enchanted labyrinth becomes a test of Aria's character and her ability to resist the forces of temptation.", 'lang': 'en', 'createdAt': '2024-01-26T10:27:52.838Z', 'updatedAt': '2024-01-26T10:27:52.838Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'axv48oyLgEwQ1rn6', 'hashRootId': 'Nzy19JpLYZJePgXv', 'isExtraTwist': False, 'closestHashRootId': 'Nzy19JpLYZJePgXv'}
