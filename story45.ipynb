# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',  # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data
new_story_data = {
    'title': 'The Enchanted Odyssey',
    'body': (
        "Embark on an enchanted odyssey with Eli, a young adventurer with an insatiable curiosity for the mystical realms. One day, while wandering "
        "through an ancient forest, Eli stumbles upon a hidden portal leading to a realm of magic and wonder. The enchanted odyssey begins, unveiling "
        "secrets that defy the laws of nature."
    ),
    'tags': ['Enchanted Odyssey', 'Adventure', 'Magic', 'Mystical Realms'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# Twist 1 data
twist1_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "In the heart of the enchanted odyssey, Eli discovers a hidden sanctuary where ancient magical beings reside. The beings, attuned to the "
        "rhythms of the cosmos, offer Eli the chance to unlock dormant magical abilities. The odyssey transforms into a magical training, where "
        "Eli learns to wield elemental forces and harmonize with the mystical energies of the enchanted realms."
    ),
    'title': 'Harmony of Elemental Magic',
    'tags': ['Hidden Sanctuary', 'Magical Beings', 'Elemental Magic', 'Cosmic Harmonization'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=twist1_data)

if response.status_code == 201:
    twist1_info = response.json()
    print(f'First Twist created successfully: {twist1_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 2 data
twist2_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist1_info['hashId'],
    'body': (
        "As Eli delves deeper into the enchanted realms, mysterious portals appear, leading to different magical landscapes. Each portal holds "
        "challenges and tests of character. Eli must navigate through illusions and make choices that impact the fabric of the enchanted odyssey."
    ),
    'title': 'Portals of Illusion',
    'tags': ['Magical Landscapes', 'Character Tests', 'Illusions', 'Enchanted Choices'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=twist2_data)

if response.status_code == 201:
    twist2_info = response.json()
    print(f'Second Twist created successfully: {twist2_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Twist 3 data
twist3_data = {
    'hashId': selected_story_hash,
    'hashParentId': twist2_info['hashId'],
    'body': (
        "In the climax of the enchanted odyssey, Eli faces a choice that will determine the fate of the magical realms. A powerful artifact, known as "
        "the 'Crown of Eternity,' emerges as the key to restoring balance. However, using its power comes with great responsibility. Eli must decide "
        "whether to safeguard the magical realms or risk the allure of wielding the Crown's unmatched magical abilities."
    ),
    'title': 'Crown of Eternity',
    'tags': ['Artifact Quest', 'Balance of Realms', 'Magical Responsibility', 'Eternal Dilemma'],
}

# Make a POST request to create the third twist
response = requests.post(twists_url, headers=headers, json=twist3_data)

if response.status_code == 201:
    twist3_info = response.json()
    print(f'Third Twist created successfully: {twist3_info}')
else:
    print(f'Error creating the third twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'eEb4lJGRBQo7g3XW', 'authorId': '1932', 'title': 'The Enchanted Odyssey', 'body': 'Embark on an enchanted odyssey with Eli, a young adventurer with an insatiable curiosity for the mystical realms. One day, while wandering through an ancient forest, Eli stumbles upon a hidden portal leading to a realm of magic and wonder. The enchanted odyssey begins, unveiling secrets that defy the laws of nature.', 'lang': 'en', 'createdAt': '2024-01-26T11:04:14.011Z', 'updatedAt': '2024-01-26T11:04:14.011Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# First Twist created successfully: {'hashId': 'GA1W7wPxQNwYVPmg', 'authorId': '1932', 'title': 'Harmony of Elemental Magic', 'body': 'In the heart of the enchanted odyssey, Eli discovers a hidden sanctuary where ancient magical beings reside. The beings, attuned to the rhythms of the cosmos, offer Eli the chance to unlock dormant magical abilities. The odyssey transforms into a magical training, where Eli learns to wield elemental forces and harmonize with the mystical energies of the enchanted realms.', 'lang': 'en', 'createdAt': '2024-01-26T11:04:16.190Z', 'updatedAt': '2024-01-26T11:04:16.190Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'eEb4lJGRBQo7g3XW', 'hashRootId': 'eEb4lJGRBQo7g3XW', 'isExtraTwist': False, 'closestHashRootId': 'eEb4lJGRBQo7g3XW'}
# Second Twist created successfully: {'hashId': 'zlaY9JdXBgJGOPME', 'authorId': '1932', 'title': 'Portals of Illusion', 'body': 'As Eli delves deeper into the enchanted realms, mysterious portals appear, leading to different magical landscapes. Each portal holds challenges and tests of character. Eli must navigate through illusions and make choices that impact the fabric of the enchanted odyssey.', 'lang': 'en', 'createdAt': '2024-01-26T11:04:17.423Z', 'updatedAt': '2024-01-26T11:04:17.423Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'GA1W7wPxQNwYVPmg', 'hashRootId': 'eEb4lJGRBQo7g3XW', 'isExtraTwist': False, 'closestHashRootId': 'eEb4lJGRBQo7g3XW'}
# Third Twist created successfully: {'hashId': 'qrXB6wAXO5KEpedN', 'authorId': '1932', 'title': 'Crown of Eternity', 'body': "In the climax of the enchanted odyssey, Eli faces a choice that will determine the fate of the magical realms. A powerful artifact, known as the 'Crown of Eternity,' emerges as the key to restoring balance. However, using its power comes with great responsibility. Eli must decide whether to safeguard the magical realms or risk the allure of wielding the Crown's unmatched magical abilities.", 'lang': 'en', 'createdAt': '2024-01-26T11:04:18.562Z', 'updatedAt': '2024-01-26T11:04:18.562Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'zlaY9JdXBgJGOPME', 'hashRootId': 'eEb4lJGRBQo7g3XW', 'isExtraTwist': False, 'closestHashRootId': 'eEb4lJGRBQo7g3XW'}
