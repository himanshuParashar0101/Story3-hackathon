# %%
import requests

# Base URL for the API
base_url = 'https://story3.com/api/v2'

# Headers for authentication
headers = {
    'accept': 'application/json',
    'x-auth-token': 'OXFyWEI2d0FSNW9FcGVkTjo3YTM3MDZlZGIxNzI3YTcyNTY1NjEyYjU1MjhlYmY5NDM4ZjE4M2IyMmZkMjViNmYzZTEzMGQ3Nzk1Yjc4N2Nm',# Replace with your actual API key
      # Replace with your actual API key
}

# URL for creating a new story
stories_url = f'{base_url}/stories'

# New story data for Story 22
new_story_data = {
    'title': 'Whispers of Jaipur',
    'body': (
        "In the vibrant city of Jaipur, 'Whispers of Jaipur' tells the tale of Meera, a skilled artisan renowned for her intricate "
        "handicrafts. As she navigates the bustling bazaars and ancient palaces, Meera discovers a hidden chamber containing ancient "
        "scrolls that unveil forgotten arts and mystical secrets.\n\n"
        "Her artistic journey becomes a quest to revive the lost arts of Jaipur and preserve the mystical heritage for generations to come."
    ),
    'tags': ['Jaipur', 'Artisan', 'Handicrafts', 'Mystical Heritage'],
}

# Make a POST request to create the new story
response = requests.post(stories_url, headers=headers, json=new_story_data)

if response.status_code == 201:
    new_story_info = response.json()
    selected_story_hash = new_story_info['hashId']
    print(f'New Story created successfully: {new_story_info}')
else:
    print(f'Error creating a new story. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# URL for creating a new twist
twists_url = f'{base_url}/twists'

# First twist data for Story 22
first_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': selected_story_hash,
    'body': (
        "As Meera delves into the ancient scrolls, she awakens mystical guardians who guide her in the creation of enchanted "
        "artworks. 'Whispers of Jaipur' transforms into a collaboration between the earthly artisan and otherworldly protectors."
    ),
    'title': 'Enchanted Collaboration',
    'tags': ['Mystical Guardians', 'Enchanted Artworks', 'Collaboration', 'Artistic Journey'],
}

# Make a POST request to create the first twist
response = requests.post(twists_url, headers=headers, json=first_twist_data)

if response.status_code == 201:
    first_twist_info = response.json()
    print(f'First Twist created successfully: {first_twist_info}')
else:
    print(f'Error creating the first twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')

# Second twist data for Story 22
second_twist_data = {
    'hashId': selected_story_hash,
    'hashParentId': first_twist_info['hashId'],
    'body': (
        "In the grand celebration of Diwali, Meera's creations come to life, radiating magical auras. 'Whispers of Jaipur' "
        "becomes a spectacle of light and color, symbolizing the harmonious blend of tradition and magic in the heart of Jaipur."
    ),
    'title': 'Diwali Illumination',
    'tags': ['Diwali Celebration', 'Magical Auras', 'Light and Color', 'Harmonious Blend'],
}

# Make a POST request to create the second twist
response = requests.post(twists_url, headers=headers, json=second_twist_data)

if response.status_code == 201:
    second_twist_info = response.json()
    print(f'Second Twist created successfully: {second_twist_info}')
else:
    print(f'Error creating the second twist. Status code: {response.status_code}')
    print(f'Error response: {response.json()}')
# Out:
# New Story created successfully: {'hashId': 'axv48oyXr2wQ1rn6', 'authorId': '1932', 'title': 'Whispers of Jaipur', 'body': "In the vibrant city of Jaipur, 'Whispers of Jaipur' tells the tale of Meera, a skilled artisan renowned for her intricate handicrafts. As she navigates the bustling bazaars and ancient palaces, Meera discovers a hidden chamber containing ancient scrolls that unveil forgotten arts and mystical secrets.\n\nHer artistic journey becomes a quest to revive the lost arts of Jaipur and preserve the mystical heritage for generations to come.", 'lang': 'en', 'createdAt': '2024-01-07T16:54:01.462Z', 'updatedAt': '2024-01-07T16:54:01.462Z', 'status': 'draft', 'monetization_option': 'dynamic'}
# First Twist created successfully: {'hashId': 'adegAJ1Q6QJOMbNl', 'authorId': '1932', 'title': 'Enchanted Collaboration', 'body': "As Meera delves into the ancient scrolls, she awakens mystical guardians who guide her in the creation of enchanted artworks. 'Whispers of Jaipur' transforms into a collaboration between the earthly artisan and otherworldly protectors.", 'lang': 'en', 'createdAt': '2024-01-07T16:54:04.280Z', 'updatedAt': '2024-01-07T16:54:04.280Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'axv48oyXr2wQ1rn6', 'hashRootId': 'axv48oyXr2wQ1rn6', 'isExtraTwist': False, 'closestHashRootId': 'axv48oyXr2wQ1rn6'}
# Second Twist created successfully: {'hashId': 'klQ46KaE8lKqVaE7', 'authorId': '1932', 'title': 'Diwali Illumination', 'body': "In the grand celebration of Diwali, Meera's creations come to life, radiating magical auras. 'Whispers of Jaipur' becomes a spectacle of light and color, symbolizing the harmonious blend of tradition and magic in the heart of Jaipur.", 'lang': 'en', 'createdAt': '2024-01-07T16:54:05.644Z', 'updatedAt': '2024-01-07T16:54:05.644Z', 'status': 'draft', 'monetization_option': 'dynamic', 'hashParentId': 'adegAJ1Q6QJOMbNl', 'hashRootId': 'axv48oyXr2wQ1rn6', 'isExtraTwist': False, 'closestHashRootId': 'axv48oyXr2wQ1rn6'}
